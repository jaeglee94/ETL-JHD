# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://www.regmovies.com/movies'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'html')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
#  <head data-lang="en">
#   <title>
#    Regal Cinemas, UA &amp; Edwards Theatres: Movie Tickets &amp; Showtimes | Regal Theatres
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Regal Cinemas, UA &amp; Edwards Theatres: Movie Tickets &amp; Showtimes | Regal Theatres" property="og:title"/>
#   <meta content="http://www.regmovies.com/movies" property="og:url"/>
#   <meta content="https://www.regmovies.com/xmedia/img/10110/cinema_card.jpg" property="og:image"/>
#   <meta content="image/jpg" property="og:image:type"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta name="description"/>
#   <meta property="og:description"/>
#   <link href="https://www.regmovies.com/movies" rel="canonical"/>
#   <link href="/xmedia/img/10110/fav.png?v=ver-2.5.32-54-g33fd499" rel="icon" type="image/png"/>
#   <link href="/xmedia/stylesheets/css/breakpoints.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/css/bootstrap/bootstrap.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/compiled_css/10110/fhmm.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/css/datepicker3.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/css/bootstrap/bootstrap-datetimepicker.min.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/css/bootstrap/bootstrap-select.min.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/css/font-awesome.min.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/compiled_css/10110/cards.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/compiled_css/10110/theme.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/compiled_css/10110/theme-mobile.css?v=ver-2.5.32-54-g33fd499" rel="stylesheet"/>
#   <link href="/xmedia/stylesheets/css/print.css?v=ver-2.5.32-54-g33fd499" media="print" rel="stylesheet"/>
#   <script src="/xmedia/js/vendor/modernizr.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#  </head>
#  <body>
#   <script>
#    var breadcrumbs = [
#             {name: "Home", link: '/'},
#             {name: "Movies", link: null}
#           ];
#   </script>
#   <script>
#    var utag_data = {
#             'page_title': 'movies_page'
#           }
#   </script>
#   <!-- TEALIUM  script-->
#   <script>
#    (function (a, b, c, d) {
#         a = '//tags.tiqcdn.com/utag/cineworld/'
#             + "us" + '/' + "prod" + '/utag.js';
#         b = document;
#         c = 'script';
#         d = b.createElement(c);
#         d.src = a;
#         d.type = 'text/java' + c;
#         d.async = true;
#         a = b.getElementsByTagName(c)[0];
#         a.parentNode.insertBefore(d, a);
#     })();
#
#     if(typeof utag_data !== 'undefined') {
#         utag_data['country'] = "us";
#         utag_data['build'] = "ver-2.5.32-54-g33fd499";
#     } else {
#         var utag_data = {
#             'country': "us",
#             'build':  "ver-2.5.32-54-g33fd499"
#         }
#     }
#   </script>
#   <section class="dark cookies">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-xs-12">
#       <span class="h2">
#        Cookies notification
#       </span>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-sm-12 col-md-8">
#       <p>
#        This website uses cookies to provide you with a better experience
#       </p>
#       <p>
#        You can adjust your cookie settings at any time at the bottom of each page. If you do not adjust your settings, you are consenting to us issuing all cookies to you
#       </p>
#      </div>
#      <div class="col-sm-12 col-md-3 col-md-push-1">
#       <ul class="list-unstyled">
#        <li>
#         <a href="/privacy">
#          <strong>
#           Find out more about cookies
#          </strong>
#         </a>
#        </li>
#        <li>
#         <a class="btn-arrow-primary dismiss-countdown" href="#">
#          <strong>
#           Continue
#          </strong>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!--HEADER START-->
#   <header-component data-location-picker-enabled="true" data-login-url="/rcc/login" data-logout-url="/rcc/logout" data-my-account-url="/rcc" data-page-type="movies" data-prediction-result-redirect-url="/theatres" data-register-url="/rcc/register">
#    <ul class="hidden menu-items">
#     <li data-description="Theatres" data-href="/theatres" data-label="Theatres" data-link-type="whatson" href="/theatres">
#     </li>
#     <li data-description="Movies" data-href="/movies" data-label="Movies" href="/movies">
#     </li>
#     <li data-description="Regal Crown Club" data-href="/regal-crown-club-info" data-label="Regal Crown Club" href="/regal-crown-club-info">
#     </li>
#     <li data-description="Current Promotions" data-href="/promotions" data-label="promotions" href="/promotions">
#     </li>
#     <li data-description="Buy Regal Gift Cards" data-href="https://store.corporateboxoffice.com/" data-label="Gift Cards" href="https://store.corporateboxoffice.com/">
#     </li>
#     <li data-description="4DX" data-href="/4dx" data-image-alt="4DX" data-image-url="/static/dam/jcr:d4014c3b-a823-465b-95d2-b0d4d064ec62" data-label="4dx" href="/4dx">
#     </li>
#     <li data-description="IMAX" data-href="/imax" data-image-alt="IMAX" data-image-url="/static/dam/jcr:07298ab6-4fe6-4dd6-992f-c0e9acdc7ccd" data-label="imax" href="/imax">
#     </li>
#     <li data-description="RPX" data-href="/rpx" data-image-alt="RPX - Regal Premium Experience" data-image-url="/static/dam/jcr:f95256cd-bf63-46f1-8211-c7cd5b775bcd" data-label="RPX" href="/rpx">
#     </li>
#     <li data-description="ScreenX" data-href="/screenx" data-image-alt="ScreenX" data-image-url="/static/dam/jcr:6381705a-bf70-438f-9407-7ce96a6a81cc" data-label="ScreenX" href="/screenx">
#     </li>
#    </ul>
#   </header-component>
#   <!--HEADER END-->
#   <movies-screen>
#   </movies-screen>
#   <!-- EXPERIENCES START -->
#   <section class="dark noBg experiences noprint last">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-xs-12">
#       <ul aria-orientation="horizontal" class="nav nav-tabs responsive" id="experiencesTabs" role="tablist">
#        <li class="hidden-xs">
#         <a aria-controls="tab_promoTab1" aria-selected="false" data-target="#tab_promoTab1" data-toggle="tab" href="#0" id="promoTab1_tab" role="tab" tabindex="0">
#          Promotions
#         </a>
#        </li>
#        <li class="hidden-xs">
#         <a aria-controls="tab_promoTab2" aria-selected="false" data-target="#tab_promoTab2" data-toggle="tab" href="#0" id="promoTab2_tab" role="tab" tabindex="0">
#          Sweepstakes
#         </a>
#        </li>
#        <li class="visible-xs active">
#         <a data-toggle="tab" href="" tabindex="0">
#         </a>
#        </li>
#        <li class="dropdown-tab">
#         <button class="navbar-toggle collapsed" data-target="#mobile-experiences" data-toggle="dropdown" type="button">
#          <span class="sr-only">
#           Toggle navigation
#          </span>
#          <i aria-hidden="true" class="fa fa-2x mobile-caret-menu">
#          </i>
#         </button>
#        </li>
#       </ul>
#       <div class="tab-content responsive">
#        <ul aria-orientation="vertical" class="dropdown-menu dropdown-tabs dark" id="mobile-experiences" role="tablist">
#         <li>
#          <a aria-controls="tab_promoTab1" aria-selected="false" data-target="#tab_promoTab1" data-toggle="tab" href="#0" role="tab" tabindex="0">
#           Promotions
#          </a>
#         </li>
#         <li>
#          <a aria-controls="tab_promoTab2" aria-selected="false" data-target="#tab_promoTab2" data-toggle="tab" href="#0" role="tab" tabindex="0">
#           Sweepstakes
#          </a>
#         </li>
#        </ul>
#        <div aria-labelledby="promoTab1_tab" class="tab-pane" id="tab_promoTab1" role="tabpanel">
#         <div class="container-fluid no-padding hidden-xs">
#          <div class="row">
#           <div class="col-xs-12 col-sm-6 col-md-4">
#            <a aria-label="Lionsgate Movie Bonus" class="card promobox-card promobox-large" href="/movies/john-wick-chapter-3-parabellum/ho00008485" target="_self">
#             <div class="card-top">
#              <img alt="Kickoff the Lionsgate Movie Bonus with Five Feet Apart, opening March 15!  Use your Regal Crown Club card when you see multiple movies from this set of Lionsgate titles and receive additional rewards including extra credits and free popcorn!  Members that see all four movies will receive a digital copy of the titles when they become available!" class="card-img-top" src="/static/dam/jcr:ed8fbfa1-f21a-4ed7-8d62-74571131db43"/>
#             </div>
#            </a>
#           </div>
#           <div class="col-xs-12 col-sm-6 col-md-4">
#            <a aria-label="Aladdin Fan Event" class="card promobox-card promobox-small" href="/movies/aladdin-3d-opening-night-fan-event/ho00009104" target="_self">
#             <div class="card-top">
#              <img alt="Aladdin Opening Night Fan Event - See the live-action adaptation of the classic Aladdin an hour before everyone else with the Aladdin Opening Night Fan Event in RealD 3D on Thursday, May 23 at 5pm!  All attendees will receive a free digital download of the film's soundtrack and Regal Crown Club members will also get a $5 small popcorn and soft drink combo!" class="card-img-top" src="/static/dam/jcr:6f35a67b-a4f4-4aae-98a2-e4a735ddd8ed"/>
#             </div>
#            </a>
#            <a aria-label="Detective Pikachu VUDU" class="card promobox-card promobox-small" href="/movies/pokemon-detective-pikachu/ho00008375" target="_self">
#             <div class="card-top">
#              <img alt="Pokemon Detective Pikachu - Movie Tickets and Showtimes - Get $3 off your purchase of Pokémon Detective Pikachu on Vudu when you use your Regal Crown Club when seeing it at Regal 5/9-5/19!" class="card-img-top" src="/static/dam/jcr:ea736db8-c3ea-4de0-b1ae-cba37c7eebe4"/>
#             </div>
#            </a>
#           </div>
#           <div class="col-xs-12 col-sm-12 col-md-4">
#            <div class="mt-lg visible-sm">
#            </div>
#            <ul class="promobox-links-list">
#             <li>
#              <a class="promobox-link" href="/regal-crown-club-info">
#               <p class="promobox-title">
#                Regal Crown Club
#               </p>
#               <p class="promobox-lead">
#                More Rewards Your Way!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/rpx">
#               <p class="promobox-title">
#                RPX
#               </p>
#               <p class="promobox-lead">
#                Experience the ultimate in movie sight and sound
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/screenx">
#               <p class="promobox-title">
#                ScreenX
#               </p>
#               <p class="promobox-lead">
#                Beyond The Frame
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="https://www.youtube.com/user/OfficialRegalMovies/">
#               <p class="promobox-title">
#                Latest Trailers
#               </p>
#               <p class="promobox-lead">
#                Watch The Latest Trailers!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/promotions">
#               <p class="promobox-title">
#                Specials &amp; Promotions
#               </p>
#               <p class="promobox-lead">
#                Find out more
#               </p>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="carousel promobox-carousel slide visible-xs" data-interval="false" data-ride="carousel" id="promoboxCarousel1">
#          <!-- Wrapper for slides -->
#          <div class="carousel-inner mt-sm" role="listbox">
#           <div class="item active">
#            <a aria-label="Lionsgate Movie Bonus" class="card promobox-card promobox-large" href="/movies/john-wick-chapter-3-parabellum/ho00008485" target="_self">
#             <div class="card-top">
#              <img alt="Kickoff the Lionsgate Movie Bonus with Five Feet Apart, opening March 15!  Use your Regal Crown Club card when you see multiple movies from this set of Lionsgate titles and receive additional rewards including extra credits and free popcorn!  Members that see all four movies will receive a digital copy of the titles when they become available!" class="card-img-top" src="/static/dam/jcr:ed8fbfa1-f21a-4ed7-8d62-74571131db43"/>
#             </div>
#            </a>
#           </div>
#           <div class="item mb-sm">
#            <a aria-label="Aladdin Fan Event" class="card promobox-card promobox-small" href="/movies/aladdin-3d-opening-night-fan-event/ho00009104" target="_self">
#             <div class="card-top">
#              <img alt="Aladdin Opening Night Fan Event - See the live-action adaptation of the classic Aladdin an hour before everyone else with the Aladdin Opening Night Fan Event in RealD 3D on Thursday, May 23 at 5pm!  All attendees will receive a free digital download of the film's soundtrack and Regal Crown Club members will also get a $5 small popcorn and soft drink combo!" class="card-img-top" src="/static/dam/jcr:6f35a67b-a4f4-4aae-98a2-e4a735ddd8ed"/>
#             </div>
#            </a>
#            <a aria-label="Detective Pikachu VUDU" class="card promobox-card promobox-small" href="/movies/pokemon-detective-pikachu/ho00008375" target="_self">
#             <div class="card-top">
#              <img alt="Pokemon Detective Pikachu - Movie Tickets and Showtimes - Get $3 off your purchase of Pokémon Detective Pikachu on Vudu when you use your Regal Crown Club when seeing it at Regal 5/9-5/19!" class="card-img-top" src="/static/dam/jcr:ea736db8-c3ea-4de0-b1ae-cba37c7eebe4"/>
#             </div>
#            </a>
#           </div>
#           <div class="item mb-sm">
#            <ul class="promobox-links-list">
#             <li>
#              <a class="promobox-link" href="/regal-crown-club-info">
#               <p class="promobox-title">
#                Regal Crown Club
#               </p>
#               <p class="promobox-lead">
#                More Rewards Your Way!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/rpx">
#               <p class="promobox-title">
#                RPX
#               </p>
#               <p class="promobox-lead">
#                Experience the ultimate in movie sight and sound
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/screenx">
#               <p class="promobox-title">
#                ScreenX
#               </p>
#               <p class="promobox-lead">
#                Beyond The Frame
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="https://www.youtube.com/user/OfficialRegalMovies/">
#               <p class="promobox-title">
#                Latest Trailers
#               </p>
#               <p class="promobox-lead">
#                Watch The Latest Trailers!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/promotions">
#               <p class="promobox-title">
#                Specials &amp; Promotions
#               </p>
#               <p class="promobox-lead">
#                Find out more
#               </p>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <!-- Indicators -->
#          <ol class="carousel-indicators">
#           <li class="active" data-slide-to="0" data-target="#promoboxCarousel1">
#           </li>
#           <li data-slide-to="1" data-target="#promoboxCarousel1">
#           </li>
#           <li data-slide-to="2" data-target="#promoboxCarousel1">
#           </li>
#          </ol>
#         </div>
#        </div>
#        <div aria-labelledby="promoTab2_tab" class="tab-pane" id="tab_promoTab2" role="tabpanel">
#         <div class="container-fluid no-padding hidden-xs">
#          <div class="row">
#           <div class="col-xs-12 col-sm-6 col-md-4">
#            <a aria-label="Rocketman Sweepstakes" class="card promobox-card promobox-large" href="https://regalcrownclub.regmovies.com/sweepstakes-rocketman-trip.html" target="_blank">
#             <div class="card-top">
#              <img alt="Rocketman Sweepstakes - Swipe your Regal Crown Club card when purchasing tickets to see Rocketman between 5/15/19 and 6/13/19 to enter to win a luxury trip to London, England and a $500 Lucky Brand gift card." class="card-img-top" src="/static/dam/jcr:4bc8ad27-7c61-401b-8ce1-c775cc8b5a55"/>
#             </div>
#            </a>
#           </div>
#           <div class="col-xs-12 col-sm-6 col-md-4">
#            <a aria-label="John Wick: Chapter 3 - Parabellum Prize Pack" class="card promobox-card promobox-small" href="https://regalcrownclub.regmovies.com/sweepstakes-john-wick-chapter-3-parabellum-prize-pack.html" target="_self">
#             <div class="card-top">
#              <img alt="John Wick: Chapter 3 - Parabellum Prize Pack" class="card-img-top" src="/static/dam/jcr:a33fa0ee-200e-4723-b078-b4aa1ae413d8"/>
#             </div>
#            </a>
#            <a aria-label="A Dog's Journey Prize Pack Giveaway" class="card promobox-card promobox-small" href="https://regalcrownclub.regmovies.com/sweepstakes-a-dog-s-journey-prize-pack.html" target="_self">
#             <div class="card-top">
#              <img alt="A Dog's Journey Prize Pack" class="card-img-top" src="/static/dam/jcr:238cf0fa-66bb-4da0-a5d1-e9c6170d82f7"/>
#             </div>
#            </a>
#           </div>
#           <div class="col-xs-12 col-sm-12 col-md-4">
#            <div class="mt-lg visible-sm">
#            </div>
#            <ul class="promobox-links-list">
#             <li>
#              <a class="promobox-link" href="/regal-crown-club-info">
#               <p class="promobox-title">
#                Regal Crown Club
#               </p>
#               <p class="promobox-lead">
#                More Rewards Your Way!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/rpx">
#               <p class="promobox-title">
#                RPX
#               </p>
#               <p class="promobox-lead">
#                Experience the ultimate in movie sight and sound
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/screenx">
#               <p class="promobox-title">
#                ScreenX
#               </p>
#               <p class="promobox-lead">
#                Beyond The Frame
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="https://www.youtube.com/user/OfficialRegalMovies/">
#               <p class="promobox-title">
#                Latest Trailers
#               </p>
#               <p class="promobox-lead">
#                Watch The Latest Trailers!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/promotions">
#               <p class="promobox-title">
#                Specials &amp; Promotions
#               </p>
#               <p class="promobox-lead">
#                Find out more
#               </p>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="carousel promobox-carousel slide visible-xs" data-interval="false" data-ride="carousel" id="promoboxCarousel2">
#          <!-- Wrapper for slides -->
#          <div class="carousel-inner mt-sm" role="listbox">
#           <div class="item active">
#            <a aria-label="Rocketman Sweepstakes" class="card promobox-card promobox-large" href="https://regalcrownclub.regmovies.com/sweepstakes-rocketman-trip.html" target="_blank">
#             <div class="card-top">
#              <img alt="Rocketman Sweepstakes - Swipe your Regal Crown Club card when purchasing tickets to see Rocketman between 5/15/19 and 6/13/19 to enter to win a luxury trip to London, England and a $500 Lucky Brand gift card." class="card-img-top" src="/static/dam/jcr:4bc8ad27-7c61-401b-8ce1-c775cc8b5a55"/>
#             </div>
#            </a>
#           </div>
#           <div class="item mb-sm">
#            <a aria-label="John Wick: Chapter 3 - Parabellum Prize Pack" class="card promobox-card promobox-small" href="https://regalcrownclub.regmovies.com/sweepstakes-john-wick-chapter-3-parabellum-prize-pack.html" target="_self">
#             <div class="card-top">
#              <img alt="John Wick: Chapter 3 - Parabellum Prize Pack" class="card-img-top" src="/static/dam/jcr:a33fa0ee-200e-4723-b078-b4aa1ae413d8"/>
#             </div>
#            </a>
#            <a aria-label="A Dog's Journey Prize Pack Giveaway" class="card promobox-card promobox-small" href="https://regalcrownclub.regmovies.com/sweepstakes-a-dog-s-journey-prize-pack.html" target="_self">
#             <div class="card-top">
#              <img alt="A Dog's Journey Prize Pack" class="card-img-top" src="/static/dam/jcr:238cf0fa-66bb-4da0-a5d1-e9c6170d82f7"/>
#             </div>
#            </a>
#           </div>
#           <div class="item mb-sm">
#            <ul class="promobox-links-list">
#             <li>
#              <a class="promobox-link" href="/regal-crown-club-info">
#               <p class="promobox-title">
#                Regal Crown Club
#               </p>
#               <p class="promobox-lead">
#                More Rewards Your Way!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/rpx">
#               <p class="promobox-title">
#                RPX
#               </p>
#               <p class="promobox-lead">
#                Experience the ultimate in movie sight and sound
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/screenx">
#               <p class="promobox-title">
#                ScreenX
#               </p>
#               <p class="promobox-lead">
#                Beyond The Frame
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="https://www.youtube.com/user/OfficialRegalMovies/">
#               <p class="promobox-title">
#                Latest Trailers
#               </p>
#               <p class="promobox-lead">
#                Watch The Latest Trailers!
#               </p>
#              </a>
#             </li>
#             <li>
#              <a class="promobox-link" href="/promotions">
#               <p class="promobox-title">
#                Specials &amp; Promotions
#               </p>
#               <p class="promobox-lead">
#                Find out more
#               </p>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <!-- Indicators -->
#          <ol class="carousel-indicators">
#           <li class="active" data-slide-to="0" data-target="#promoboxCarousel2">
#           </li>
#           <li data-slide-to="1" data-target="#promoboxCarousel2">
#           </li>
#           <li data-slide-to="2" data-target="#promoboxCarousel2">
#           </li>
#          </ol>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!-- EXPERIENCES END-->
#   <!-- BLOG START -->
#   <!-- BLOG END -->
#   <!-- FOOTER START -->
#   <section class="dark footer noprint">
#    <div class="container-fluid">
#     <!--FOR DESKTOP-->
#     <div class="row hidden-xs">
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         Corporate Sales
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/discount-tickets" target="_self">
#         Discount Movie Tickets
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/discount-tickets/premiere-movie-ticket-2" target="_self">
#         Ultimate Movie Pack
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/private-screenings" target="_self">
#         Private Screenings
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/theatre-church" target="_self">
#         Theatre Church
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/business-events" target="_self">
#         Business Events
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/group-sales" target="_self">
#         Group Sales
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/educational-screenings" target="_self">
#         IMAX Education Screenings
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/rcc/birthday-party" target="_self">
#         Birthday Parties
#        </a>
#       </p>
#      </div>
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         About Regal
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/about" target="_self">
#         About
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/regal-crown-club-info" target="_self">
#         Regal Crown Club
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/promotions" target="_self">
#         Promotions
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/about/partners" target="_self">
#         Partners
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/help/faq" target="_self">
#         FAQ
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/about/job-opportunities" target="_self">
#         Job Opportunities
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/privacy" target="_self">
#         Privacy Policy
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/tos" target="_self">
#         Terms of Use
#        </a>
#       </p>
#      </div>
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         Contact
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/rcc/contact-us" target="_self">
#         Contact Us
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/about/community-affairs" target="_self">
#         Community Affairs
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="http://www.ncm.com/" target="_self">
#         Advertise With Regal
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/theatre/technology" target="_self">
#         Theatre Technologies
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/theatre-list" target="_self">
#         Theatre List
#        </a>
#       </p>
#      </div>
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         Stay in Touch
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.facebook.com/RegalMovies" target="_self">
#         Facebook
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://twitter.com/RegalMovies" target="_self">
#         Twitter
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.youtube.com/user/OfficialRegalMovies" target="_self">
#         YouTube
#        </a>
#       </p>
#      </div>
#     </div>
#     <!--FOR DESKTOP END-->
#     <!--FOR MOBILE-->
#     <div class="row visible-xs">
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         Corporate Sales
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/discount-tickets" target="_self">
#         Discount Movie Tickets
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/discount-tickets/premiere-movie-ticket-2" target="_self">
#         Ultimate Movie Pack
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/private-screenings" target="_self">
#         Private Screenings
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/theatre-church" target="_self">
#         Theatre Church
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/business-events" target="_self">
#         Business Events
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/group-sales" target="_self">
#         Group Sales
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.corporateboxoffice.com/educational-screenings" target="_self">
#         IMAX Education Screenings
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/rcc/birthday-party" target="_self">
#         Birthday Parties
#        </a>
#       </p>
#      </div>
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         About Regal
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/about" target="_self">
#         About
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/regal-crown-club-info" target="_self">
#         Regal Crown Club
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/promotions" target="_self">
#         Promotions
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/about/partners" target="_self">
#         Partners
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/static/en/us/help/faq" target="_self">
#         FAQ
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/about/job-opportunities" target="_self">
#         Job Opportunities
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/privacy" target="_self">
#         Privacy Policy
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/tos" target="_self">
#         Terms of Use
#        </a>
#       </p>
#      </div>
#     </div>
#     <div class="row visible-xs">
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         Contact
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/rcc/contact-us" target="_self">
#         Contact Us
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/about/community-affairs" target="_self">
#         Community Affairs
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="http://www.ncm.com/" target="_self">
#         Advertise With Regal
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/theatre/technology" target="_self">
#         Theatre Technologies
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="/theatre-list" target="_self">
#         Theatre List
#        </a>
#       </p>
#      </div>
#      <div class="col-xs-6 col-sm-3 footer-group">
#       <h4 class="h5 footer-group-name">
#        <strong>
#         Stay in Touch
#        </strong>
#       </h4>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.facebook.com/RegalMovies" target="_self">
#         Facebook
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://twitter.com/RegalMovies" target="_self">
#         Twitter
#        </a>
#       </p>
#       <p class="footer-group-item">
#        <a class="posMessageItemLink" href="https://www.youtube.com/user/OfficialRegalMovies" target="_self">
#         YouTube
#        </a>
#       </p>
#      </div>
#     </div>
#     <!--FOR MOBILE END-->
#     <div class="row">
#      <div class="col-xs-12 text-center rights">
#       <p>
#        2019 Regal, a subsidiary of Cineworld Group. All Rights Reserved.
#       </p>
#       <p>
#        All rights reserved Regal Theatres
#        <span>
#         2019
#        </span>
#        ©
#       </p>
#      </div>
#     </div>
#    </div>
#   </section>
#   <div id="ajax_loader" style="display: none;">
#    <img alt="Loading the page" src="/xmedia/img/ajax-loader-poster.gif"/>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="share-login-register" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <a class="btn btn-grey pull-left close pull-right visible-xs" data-dismiss="modal" href="#">
#        Close
#       </a>
#       <h4 class="modal-title">
#        Login or register to My Cineworld
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#       </p>
#       <ul class="list-inline login-buttons hidden-xs">
#        <li>
#         <a class="btn btn-social-share fb" href="#">
#          Share on Facebook
#         </a>
#        </li>
#        <li>
#         <a class="btn btn-social-share tw" href="#">
#          Share on Twitter
#         </a>
#        </li>
#        <li>
#         <a class="btn btn-social-share gplus" href="#">
#          Share on Google Plus
#         </a>
#        </li>
#        <li>
#         <a class="btn btn-link" href="#">
#          Share via email
#         </a>
#        </li>
#       </ul>
#       <div class="login-buttons visible-xs">
#        <a class="btn btn-block btn-social-share fb" href="#">
#         Share on Facebook
#        </a>
#        <a class="btn btn-block btn-social-share tw" href="#">
#         Share on Twitter
#        </a>
#        <a class="btn btn-block btn-social-share gplus" href="#">
#         Share on Google Plus
#        </a>
#        <a class="btn btn-block btn-link" href="#">
#         Share via email
#        </a>
#       </div>
#      </div>
#      <div class="border-sep">
#      </div>
#      <div class="modal-footer">
#       <a class="pull-left close hidden-xs" data-dismiss="modal" href="#">
#        Close
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="road-block" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <a class="btn btn-grey pull-left close pull-right visible-xs" data-dismiss="modal" href="#">
#        Close
#       </a>
#       <h4 class="modal-title">
#        Login or register to My Cineworld
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        Take a minute to become part of the My Cineworld community
#       </p>
#      </div>
#      <div class="border-sep">
#      </div>
#      <div class="modal-footer">
#       <a class="pull-left close hidden-xs" data-dismiss="modal" href="#">
#        Close
#       </a>
#       <ul class="list-inline login-buttons hidden-xs">
#        <li>
#         <a class="btn-arrow-primary register" href="">
#          <strong>
#           Register
#          </strong>
#         </a>
#        </li>
#        <li>
#         <a class="btn-arrow-primary login" href="">
#          <strong>
#           Login
#          </strong>
#         </a>
#        </li>
#        <li>
#         <a class="btn-facebook" href="javascript:fb_login();">
#          Connect with Facebook
#         </a>
#        </li>
#       </ul>
#       <div class="login-buttons visible-xs">
#        <a class="btn btn-block btn-primary register" data-title="title-share-article" href="">
#         <strong>
#          Register
#         </strong>
#        </a>
#        <a class="btn btn-block btn-primary login" data-title="title-share-article" href="">
#         <strong>
#          Login
#         </strong>
#        </a>
#        <a class="btn btn-block btn-facebook" href="#" onclick="javascript:fb_login();">
#         Connect with Facebook
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" data-backdrop="static" data-keyboard="false" id="loginModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <p class="loaderLight">
#       <img alt="Loading the page" src="/xmedia/img/loader-light.gif"/>
#      </p>
#      <p class="text-center">
#       Logging in. Please wait.
#      </p>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" data-backdrop="static" data-keyboard="false" id="registerModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <p class="loaderLight">
#       <img alt="Loading the page" src="/xmedia/img/loader-light.gif"/>
#      </p>
#      <p class="text-center">
#       Processing registration form. Please wait.
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="selectpicker-dropdown-container npm-quickbook">
#    <div class="title visible-xs">
#    </div>
#   </div>
#   <!-- FOOTER END -->
#   <!-- VERSION: ver-2.5.32-54-g33fd499 -->
#   <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyBA3VeA-xV8Rgkl88ttMmHqtw7j7dfpTK0&amp;libraries=places&amp;language=en">
#   </script>
#   <script>
#    window.translationObject = {
#   "homepageTitle": "Book Now",
#   "search.noresults": "No search results",
#   "attr.pg13.desc": "Some material may be inappropriate for children under 13.",
#   "attr.g.desc": "All ages admitted.",
#   "attr.r.desc": "Under 17 requires accompanying parent or adult guardian.",
#   "attr.nc17.desc": "No one 17 and under admitted.",
#   "attr.nr.desc": "Not rated. ",
#   "changeDate": "Change date",
#   "locationScreen.theatersNearYouTitle": "Movie Theatres Near You",
#   "locationScreen.notheatresFoundInfo": "We could not find any movie theatres near your location. Try another location or browse all Regal Cinemas below.",
#   "locationScreen.distanceFromYou": "miles from you",
#   "moviesScreen.moviesScreenTitle": "Movies",
#   "attr.1-week": "",
#   "attr.1-week.desc": "",
#   "attr.adv-group": "Advanced Group Sale",
#   "attr.adv-group.desc": "",
#   "attr.all-listening-devices": "",
#   "attr.all-listening-devices.desc": "",
#   "attr.auro": "Auro",
#   "attr.auro.desc": "Experience sound in the 3D.",
#   "attr.big-aud.desc": "",
#   "attr.big-newport": "Big Newport",
#   "attr.big-newport.desc": "Big Newport",
#   "attr.big-valley.desc": "",
#   "attr.butt-kick.desc": "Enhanced with Buttkicker Recliners - Experience every seat-shaking moment.",
#   "attr.cafe.desc": "",
#   "attr.chinese": "Chinese",
#   "attr.chinese.desc": "This film is presented in Chinese.",
#   "attr.cinema-art": "Cinema Art",
#   "attr.cinema-art.desc": "",
#   "attr.colosseum": "Colosseum",
#   "attr.colosseum.desc": "",
#   "attr.cry-room": "Cry Room",
#   "attr.cry-room.desc": "Private room with independently-controlled stereo sound system.",
#   "attr.digital.desc": "",
#   "attr.digital-s.desc": "",
#   "attr.director": "Director",
#   "attr.director.desc": "Ultra-luxurious recliners and the latest digital cinema technology with at-your-seat service.",
#   "attr.downstairs.desc": "",
#   "attr.drive-in.desc": "",
#   "attr.dts-x": "DTS-X",
#   "attr.dts-x.desc": "",
#   "attr.dv": "Descriptive Video",
#   "attr.dv.desc": "Descriptive Video devices provide audio descriptions of the movie to accommodate the needs of visually impaired guests. Devices available by request.",
#   "attr.egyptian.desc": "This film is presented in Egyptian.",
#   "attr.escape": "Barco Escape",
#   "attr.escape.desc": "",
#   "attr.exclude-ad": "Exclude from Ads",
#   "attr.exclude-ad.desc": "",
#   "attr.fp": "",
#   "attr.fp.desc": "",
#   "attr.game-room.desc": "",
#   "attr.ge-3d.desc": "",
#   "attr.giant": "Giant Screen",
#   "attr.giant.desc": "",
#   "attr.grand-infi": "Grand Infinity",
#   "attr.grand-infi.desc": "Our signature auditorium, The Warren Grand Infinity Auditorium features the largest screens in the area, 64 channel Dolby Atmos sound, and America's FIRST and only 4K Infinity Laser 3D projection.",
#   "attr.hale-ikua.desc": "",
#   "attr.hollywood.desc": "",
#   "attr.interlock": "Interlock",
#   "attr.interlock.desc": "",
#   "attr.ksk.desc": "",
#   "attr.modern-cin.desc": "",
#   "attr.no-pass": "No Passes",
#   "attr.no-pass.desc": "Restrictions apply. Please refer to conditions on your pass or contact the theatre for more information.",
#   "attr.no-pass-ss.desc": "Restrictions apply. Please refer to conditions on your pass or contact the theatre for more information.",
#   "attr.oc.desc": "",
#   "attr.party-room": "Party Room",
#   "attr.party-room.desc": "",
#   "attr.preferred-parking.desc": "",
#   "attr.premier.desc": "",
#   "attr.premiere.desc": "",
#   "attr.print-at-home": "Print at Home",
#   "attr.print-at-home.desc": "",
#   "attr.recliner.desc": "This auditorium features ultra-comfy recliner seats with adjustable settings.",
#   "attr.reserved.desc": "This showtime features reserved seating so you can pick your seats ahead of time.",
#   "attr.screen-room.desc": "Reserved seating stadium auditoriums featuring plush recliner seats with seat heaters.",
#   "attr.sensory": "Sensory",
#   "attr.sensory.desc": "Sensory Friendly. Sound Lower. Lights Brighter.",
#   "attr.stadium.desc": "Stadium seating auditorium",
#   "attr.the-palace.desc": "",
#   "attr.thx": "THX",
#   "attr.thx.desc": "",
#   "attr.univ-south": "",
#   "attr.univ-south.desc": "",
#   "attr.upstairs.desc": "",
#   "attr.warr-grand": "The Warren Grand",
#   "attr.warr-grand.desc": "Our signature auditorium, The Warren Grand Auditorium features the largest screens in the area.",
#   "attr.wheelchair-accessible.desc": "This showing is wheelchair accessible.",
#   "attr.35-mm": "35mm",
#   "attr.35-mm.desc": "35mm",
#   "attr.70-mm.desc": "",
#   "attr.cc": "Closed Caption",
#   "attr.cc.desc": "Closed Captioning devices display a movie's dialogue and sound effects as text; captions are not shown on the main screen. Devices available by request.",
#   "attr.dbox.desc": "Next-level movie experience with seat movement and vibration effects that engage you in the action.",
#   "attr.hfr.desc": "This film is shown in high frame rate.",
#   "attr.2d.desc": "Standard Format",
#   "attr.3d.desc": "Digital 3D technology displays ultra-lifelike images. RealD is the most widely used digital 3D cinema technology. 3D glasses provided by theatre.",
#   "attr.dolby-atmos.desc": "Dolby Atmos transports you into the movie with breathtaking, 360° sound that fills the theatre and flows all around you.",
#   "attr.3d-vip": "3D VIP",
#   "attr.3d-vip.desc": "",
#   "attr.4dx.desc": "A premier movie experience that combines digital 3D technology with seat movement plus realistic effects like wind, fog and scents. NOTICE: When purchasing a 4DX ticket you confirm that you understand, agree to and will comply with the 4DX Safety Guidelines. You enter at your own risk and the Regal Theatre and 4DX accept no liability for any injury or damage suffered as a result of viewing a presentation in a theatre equipped with 4DX Motion Chairs. 4DX available for guests ages 4 and up. All children must be 3.5 feet or taller. For more info, please see theatre attendant.",
#   "attr.4k.desc": "The most advanced theatre projection technology, it displays twice as many on-screen pixels as standard 2K projection. 4K digital projection produces a clear, bright, high-resolution image with absolute stability and cleanliness, combined with uncompressed digital sound for a powerful movie-going experience.",
#   "attr.imax.desc": "IMAX features high-quality images, customized theater geometry, and laser-aligned digital sound.",
#   "attr.imax-3d.desc": "",
#   "attr.imax-3d-vip.desc": "IMAX 3D VIP showings offer a luxurious experience with a full-service lounge, reserved king size recliners, gourmet food menu, and extensive beer and wine selections.",
#   "attr.imax-vip": "IMAX VIP",
#   "attr.imax-vip.desc": "IMAX VIP showings offer a luxurious experience with a full-service lounge, reserved king size recliners, gourmet food menu, and extensive beer and wine selections.",
#   "attr.rpx.desc": "RPX auditoriums feature a large screen, digital projection, and surround sound.",
#   "attr.rpx-3d": "RPX 3D",
#   "attr.rpx-3d.desc": "RPX auditoriums feature a large screen, digital projection, and surround sound.",
#   "attr.rpx-3d-vip": "RPX 3D VIP",
#   "rpx-3d-vip.desc": "RPX auditoriums feature a large screen, digital projection, and surround sound.",
#   "attr.rpx-vip": "RPX VIP",
#   "attr.rpx-vip.desc": "RPX auditoriums feature a large screen, digital projection, and surround sound.",
#   "attr.vip.desc": "VIP showings offer a luxurious experience with a full-service lounge, reserved king size recliners, gourmet food menu, and extensive beer and wine selections.",
#   "attr.dubbed.desc": "Please note this is a dubbed screening.",
#   "attr.hindi.desc": "This film is presented in Hindi.",
#   "attr.korean-sub.desc": "This Film is presented in Korean language.",
#   "attr.spanish.desc": "This film is presented in Spanish.",
#   "attr.spanish-dub": "Spanish Dubbed",
#   "attr.spanish-dub.desc": "The audio for this film has had the sound replaced with a Spanish voice-over.",
#   "attr.sub-titled.desc": "Please note this is a subtitled screening.",
#   "attr.tamil.desc": "This film is presented in Tamil.",
#   "attr.telugu.desc": "This film is presented in Telugu.",
#   "showtimeDetailsTitle": "Showtime Details",
#   "moviesScreen.trailer-incentives": "Trailer Incentives",
#   "moviesScreen.now-playing": "Now Playing",
#   "moviesScreen.featured": "Featured",
#   "moviesScreen.promoted-now-playing": "Promoted Now Playing",
#   "moviesScreen.promoted-coming-soon": "Promoted Coming Soon",
#   "moviesScreen.coming-soon": "Coming Soon",
#   "moviesScreen.family-friendly": "Family Friendly",
#   "moviesScreen.cinema-art": "Cinema Art",
#   "alert.updateLocation": "Please update your location to view available showtimes.",
#   "noScreeningsForLocation": "There are no screenings near your location. Please try a different location.",
#   "noMoviesForLocation": "We could not find any movies showing in this format near your location at this time. Please try a different location.",
#   "preordersHeading": "PRE-ORDER YOUR TICKETS NOW",
#   "locationpicker.map.marker": "Map Marker Icon",
#   "alt.loader": "Loading the page",
#   "alt.right.arrow": "Move right button",
#   "alt.left.arrow": "Move left button",
#   "alt.UserIcon": "User icon",
#   "google.static.map.description": "google map",
# ...
#   "attr.first-subbed-lang-ml": "",
#   "attr.first-subbed-lang-mix": "",
#   "attr.first-subbed-lang-nn": "",
#   "attr.first-subbed-lang-pk": "",
#   "attr.first-subbed-lang-fa": "",
#   "attr.first-subbed-lang-pl": "",
#   "attr.first-subbed-lang-pt": "",
#   "attr.first-subbed-lang-pa": "",
#   "attr.first-subbed-lang-ro": "",
#   "attr.first-subbed-lang-ru": "",
#   "attr.first-subbed-lang-ru-fr": "",
#   "attr.first-subbed-lang-sk": "",
#   "attr.first-subbed-lang-es": "",
#   "attr.first-subbed-lang-es-cl": "",
#   "attr.first-subbed-lang-es-pe": "",
#   "attr.first-subbed-lang-sv": "",
#   "attr.first-subbed-lang-ta": "",
#   "attr.first-subbed-lang-te": "",
#   "attr.first-subbed-lang-tr": "",
#   "attr.first-subbed-lang-without": "",
#   "attr.first-subbed-lang-th": "",
#   "attr.first-subbed-lang-sl": "",
#   "attr.first-subbed-lang-ka": "",
#   "attr.first-subbed-lang-fi": "",
#   "attr.first-subbed-lang-mn": "",
#   "attr.first-subbed-lang-sr": "",
#   "attr.first-subbed-lang-hr": "",
#   "attr.first-subbed-lang-id": "",
#   "attr.first-subbed-lang-dz": "",
#   "attr.second-subbed-lang-ar": "",
#   "attr.second-subbed-lang-bg": "",
#   "attr.second-subbed-lang-zh": "",
#   "attr.second-subbed-lang-cs": "",
#   "attr.second-subbed-lang-da": "",
#   "attr.second-subbed-lang-nl": "",
#   "attr.second-subbed-lang-en-fa": "",
#   "attr.second-subbed-lang-en-fr": "",
#   "attr.second-subbed-lang-en-de-fr": "",
#   "attr.second-subbed-lang-en-ru": "",
#   "attr.second-subbed-lang-en-uk": "",
#   "attr.second-subbed-lang-en-au": "",
#   "attr.second-subbed-lang-en-ca": "",
#   "attr.second-subbed-lang-en-gb": "",
#   "attr.second-subbed-lang-en-us": "",
#   "attr.second-subbed-lang-fr-ca": "",
#   "attr.second-subbed-lang-fr-fr": "",
#   "attr.second-subbed-lang-de": "",
#   "attr.second-subbed-lang-he": "",
#   "attr.second-subbed-lang-he-en": "",
#   "attr.second-subbed-lang-he-fr": "",
#   "attr.second-subbed-lang-he-ru": "",
#   "attr.second-subbed-lang-hi": "",
#   "attr.second-subbed-lang-hu": "",
#   "attr.second-subbed-lang-is": "",
#   "attr.second-subbed-lang-it": "",
#   "attr.second-subbed-lang-ja": "",
#   "attr.second-subbed-lang-ko": "",
#   "attr.second-subbed-lang-ml": "",
#   "attr.second-subbed-lang-mix": "",
#   "attr.second-subbed-lang-nn": "",
#   "attr.second-subbed-lang-pk": "",
#   "attr.second-subbed-lang-fa": "",
#   "attr.second-subbed-lang-pl": "",
#   "attr.second-subbed-lang-pt": "",
#   "attr.second-subbed-lang-pa": "",
#   "attr.second-subbed-lang-ro": "",
#   "attr.second-subbed-lang-ru": "",
#   "attr.second-subbed-lang-ru-fr": "",
#   "attr.second-subbed-lang-sk": "",
#   "attr.second-subbed-lang-es": "",
#   "attr.second-subbed-lang-es-cl": "",
#   "attr.second-subbed-lang-es-pe": "",
#   "attr.second-subbed-lang-sv": "",
#   "attr.second-subbed-lang-ta": "",
#   "attr.second-subbed-lang-te": "",
#   "attr.second-subbed-lang-tr": "",
#   "attr.second-subbed-lang-without": "",
#   "attr.second-subbed-lang-th": "",
#   "attr.second-subbed-lang-sl": "",
#   "attr.second-subbed-lang-ka": "",
#   "attr.second-subbed-lang-fi": "",
#   "attr.second-subbed-lang-mn": "",
#   "attr.second-subbed-lang-sr": "",
#   "attr.second-subbed-lang-hr": "",
#   "attr.second-subbed-lang-id": "",
#   "attr.second-subbed-lang-dz": "",
#   "attr.dubbed-lang-ar": "",
#   "attr.dubbed-lang-bg": "",
#   "attr.dubbed-lang-zh": "",
#   "attr.dubbed-lang-cs": "",
#   "attr.dubbed-lang-da": "",
#   "attr.dubbed-lang-nl": "",
#   "attr.dubbed-lang-en-fa": "",
#   "attr.dubbed-lang-en-fr": "",
#   "attr.dubbed-lang-en-de-fr": "",
#   "attr.dubbed-lang-en-ru": "",
#   "attr.dubbed-lang-en-uk": "",
#   "attr.dubbed-lang-en-au": "",
#   "attr.dubbed-lang-en-ca": "",
#   "attr.dubbed-lang-en-gb": "",
#   "attr.dubbed-lang-en-us": "",
#   "attr.dubbed-lang-fr-ca": "",
#   "attr.dubbed-lang-fr-fr": "",
#   "attr.dubbed-lang-de": "",
#   "attr.dubbed-lang-he": "",
#   "attr.dubbed-lang-he-en": "",
#   "attr.dubbed-lang-he-fr": "",
#   "attr.dubbed-lang-he-ru": "",
#   "attr.dubbed-lang-hi": "",
#   "attr.dubbed-lang-hu": "",
#   "attr.dubbed-lang-is": "",
#   "attr.dubbed-lang-it": "",
#   "attr.dubbed-lang-ja": "",
#   "attr.dubbed-lang-ko": "",
#   "attr.dubbed-lang-ml": "",
#   "attr.dubbed-lang-mix": "",
#   "attr.dubbed-lang-nn": "",
#   "attr.dubbed-lang-pk": "",
#   "attr.dubbed-lang-fa": "",
#   "attr.dubbed-lang-pl": "",
#   "attr.dubbed-lang-pt": "",
#   "attr.dubbed-lang-pa": "",
#   "attr.dubbed-lang-ro": "",
#   "attr.dubbed-lang-ru": "",
#   "attr.dubbed-lang-ru-fr": "",
#   "attr.dubbed-lang-sk": "",
#   "attr.dubbed-lang-es": "",
#   "attr.dubbed-lang-es-cl": "",
#   "attr.dubbed-lang-es-pe": "",
#   "attr.dubbed-lang-sv": "",
#   "attr.dubbed-lang-ta": "",
#   "attr.dubbed-lang-te": "",
#   "attr.dubbed-lang-tr": "",
#   "attr.dubbed-lang-without": "",
#   "attr.dubbed-lang-th": "",
#   "attr.dubbed-lang-sl": "",
#   "attr.dubbed-lang-ka": "",
#   "attr.dubbed-lang-fi": "",
#   "attr.dubbed-lang-mn": "",
#   "attr.dubbed-lang-sr": "",
#   "attr.dubbed-lang-hr": "",
#   "attr.dubbed-lang-id": "",
#   "attr.dubbed-lang-dz": ""
# }
#   </script>
#   <script>
#    var $loaderLight = '<p class="loaderLight"><img th:alt="#{alt.loader}" src="/xmedia/img/loader-light.gif"></p>';
#       var $loaderDark = '<p class="loaderDark"><img th:alt="#{alt.loader}" src="/xmedia/img/loader-dark.gif"></p>';
#       var qbApiUrl = JSON.parse('"\/us\/data-api-service"');
#       var gcsApiUrl = "";
#       var geolocationGoogleApiKey = "AIzaSyBA3VeA-xV8Rgkl88ttMmHqtw7j7dfpTK0";
#       var geolocationBingApiKey = "AjeZQ3pYNkrJBKJIwfczBVh9BX5z0dFXNaxRLrca3ix3NhKDhKi24hdLUEuMkSN4";
#       var geolocationGoogleZeroResultsFallback = false;
#       var geolocationTimeout = "5000";
#       var languageDisplayMode = "simple";
#       var displayNoSubtitlesInfo = false;
#       var excludedPreordersAttributes = "event";
#       var languages = {"en_US":"EN"};
#       var wmParams = {
#           facebookAppId: "1011978595498189"
#         },
#         appVersion = "ver-2.5.32-54-g33fd499",
#         isRtl = false,
#         resourceFolder = '/xmedia/img/10110',
#         tenantId = '10110',
#         apiSitesList = [{"externalCode":"0736","uri":"\/theatres\/regal-austell","name":"Regal @ Austell","filename":null,"latitude":33.8683,"longitude":-84.6267,"address":{"address1":"2480 East-West Connnector Road","address2":null,"address3":null,"address4":null,"city":"Austell","state":"GA","postalCode":"30106"}},{"externalCode":"0252","uri":"\/theatres\/regal-aiken-mall","name":"Regal Aiken Mall","filename":null,"latitude":33.5042,"longitude":-81.7173,"address":{"address1":"300 East Gate Drive","address2":null,"address3":null,"address4":null,"city":"Aiken","state":"SC","postalCode":"29802"}},{"externalCode":"0939","uri":"\/theatres\/regal-alamo-quarry","name":"Regal Alamo Quarry","filename":null,"latitude":29.4993,"longitude":-98.4798,"address":{"address1":"255 E.Basse","address2":null,"address3":null,"address4":null,"city":"San Antonio","state":"TX","postalCode":"78209"}},{"externalCode":"0833","uri":"\/theatres\/regal-albany-cinemas","name":"Regal Albany Cinemas","filename":null,"latitude":44.6295,"longitude":-123.0721,"address":{"address1":"1350 SE Waverly Drive","address2":null,"address3":null,"address4":null,"city":"Albany","state":"OR","postalCode":"97322"}},{"externalCode":"0909","uri":"\/theatres\/regal-alderwood-rpx","name":"Regal Alderwood \u0026 RPX","filename":null,"latitude":47.8323,"longitude":-122.2793,"address":{"address1":"3501 184th St. SW","address2":null,"address3":null,"address4":null,"city":"Lynnwood","state":"WA","postalCode":"98037"}},{"externalCode":"1933","uri":"\/theatres\/regal-aliante-imax","name":"Regal Aliante \u0026 IMAX","filename":null,"latitude":36.2921,"longitude":-115.1783,"address":{"address1":"7300 Aliante Parkway","address2":null,"address3":null,"address4":null,"city":"North Las Vegas","state":"NV","postalCode":"89084"}},{"externalCode":"0680","uri":"\/theatres\/regal-american-mall","name":"Regal American Mall","filename":null,"latitude":40.7378,"longitude":-84.1655,"address":{"address1":"2830 West Elm Street","address2":null,"address3":null,"address4":null,"city":"Lima","state":"OH","postalCode":"45805"}},{"externalCode":"0661","uri":"\/theatres\/regal-arbor-great-hills","name":"Regal Arbor @ Great Hills","filename":null,"latitude":30.3958,"longitude":-97.7488,"address":{"address1":"9828 Great Hills Trail","address2":null,"address3":null,"address4":null,"city":"Austin","state":"TX","postalCode":"78759"}},{"externalCode":"0392","uri":"\/theatres\/regal-arbor-place-imax","name":"Regal Arbor Place \u0026 IMAX","filename":null,"latitude":33.7215,"longitude":-84.7748,"address":{"address1":"6600 Douglas Blvd.","address2":null,"address3":null,"address4":null,"city":"Douglasville","state":"GA","postalCode":"30135"}},{"externalCode":"1730","uri":"\/theatres\/regal-arnot-mall","name":"Regal Arnot Mall","filename":null,"latitude":42.1542,"longitude":-76.8758,"address":{"address1":"3300 Chambers Rd","address2":null,"address3":null,"address4":null,"city":"Horseheads","state":"NY","postalCode":"14845"}},{"externalCode":"1812","uri":"\/theatres\/regal-arroyo-grande","name":"Regal Arroyo Grande","filename":null,"latitude":35.1284,"longitude":-120.5989,"address":{"address1":"1160 W Branch Street","address2":null,"address3":null,"address4":null,"city":"Arroyo Grande","state":"CA","postalCode":"93420"}},{"externalCode":"1346","uri":"\/theatres\/regal-atlantic-station-screenx-imax-rpx-vip","name":"Regal Atlantic Station ScreenX, IMAX, RPX \u0026 VIP","filename":null,"latitude":33.7938,"longitude":-84.396,"address":{"address1":"261 19th Street NW, Suite 1250","address2":null,"address3":null,"address4":null,"city":"Atlanta","state":"GA","postalCode":"30363"}},{"externalCode":"0688","uri":"\/theatres\/regal-atlas-park","name":"Regal Atlas Park","filename":null,"latitude":40.709,"longitude":-73.8705,"address":{"address1":"80-28 Cooper Ave, Suite #6216","address2":null,"address3":null,"address4":null,"city":"Glendale","state":"NY","postalCode":"11385"}},{"externalCode":"1823","uri":"\/theatres\/regal-auburn ...
#         pluginLocale = "en-us", // e.g. en-gb, pl-pl, he-il
#         selectedLocale = "en_US", // e.g. en_GB, pl_PL, he_IL
#         attributesDubSub = {
#           'subbed': "Subtitled",
#           'dubbed': "Dubbed",
#           'sub': "Subtitled",
#           'dub': "Dubbed"
#         };
#       window.apiSitesList = apiSitesList;
#       window.qbApiUrl = qbApiUrl;
#       window.gcsApiUrl = gcsApiUrl;
#       window.tenantId = tenantId;
#       window.selectedLocale = selectedLocale;
#       window.isRtl = isRtl;
#       window.languages = languages;
#       window.geolocationGoogleApiKey = 'AIzaSyDQS_gtIEx1yPq024rH9_umO8j4TTnK0ZA';// geolocationGoogleApiKey;
#       window.geolocationBingApiKey = geolocationBingApiKey;
#       window.geolocationGoogleZeroResultsFallback = geolocationGoogleZeroResultsFallback;
#       window.geolocationTimeout = geolocationTimeout;
#       window.languageDisplayMode = languageDisplayMode;
#       window.excludedPreordersAttributes = excludedPreordersAttributes;
#       window.displayNoSubtitlesInfo = displayNoSubtitlesInfo;
#
#       window.translationObject = Object.assign({}, window.translationObject);
#   </script>
#   <script src="/xmedia/js/config.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/jsMessages.js?lang=en_US&amp;v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/polyfills/customEvents-polyfill.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.mobile.custom.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.jloggins.1.0.2.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/json3.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/css_browser_selector.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="//www.youtube.com/iframe_api">
#   </script>
#   <script src="/xmedia/js/vendor/handlebars-v4.0.5.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/moment.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/moment-timezone.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/moment-locale.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/touchable.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/bootstrap.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/bootstrap-datepicker.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/bootstrap-datepicker-locale.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/bootstrap-select.custom.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/bootstrap-rating-input.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/slick.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/tooltip.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.scrollTo.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.unveil.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.highlight.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/searchbox.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/user-action-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/cinema-search.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.ba-throttle-debounce.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/jquery.waypoints.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/scripts.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/unison.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/vendor/js.cookie.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/cards.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/components/showtimeDatepicker.component.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/router.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/object-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/svg-converter-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/msg-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/youtube-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/nav-tabs-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/location.services.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/screening.types.handler.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/common.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/login-service.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/common-init.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/poster_modal.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/menu.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/header-module-bundle.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/rcc-events-bundle.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/quicksearch-component-bundle.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/lang_chooser.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/focus-visible.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/methods/cookies-methods.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script>
#    var tealium_category = 'movies';
#   </script>
#   <script src="/xmedia/js/promobox.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#   <script src="/xmedia/js/movies-page-bundle.min.js?v=ver-2.5.32-54-g33fd499">
#   </script>
#  </body>
# </html>

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_="PosterSlide")
print(results[0])
# Out:
# <div class="PosterSlide" data-reactid="221"><a aria-disabled="" aria-label="Avengers: Endgame" class="Link" data-reactid="222" href="/movies/avengers-endgame-45840" itemprop="url"><picture class="Picture--rectangle" data-reactid="223"><source data-reactid="224" media="(min-width: 767px)" srcset="https://amc-theatres-res.cloudinary.com/image/upload/f_auto,fl_lossy,h_600,q_auto,w_400/v1553695740/amc-cdn/production/2/movies/45800/45840/PosterDynamic/75045.jpg"/><img alt="Avengers: Endgame" data-reactid="225" src="https://amc-theatres-res.cloudinary.com/image/upload/f_auto,fl_lossy,h_300,q_auto,w_200/v1553695740/amc-cdn/production/2/movies/45800/45840/PosterDynamic/75045.jpg"/></picture></a><div class="PosterContent" data-reactid="226"></div></div>

# %%
title = results[0].find('a')['aria-label']
title
# Out:
# 'Avengers: Endgame'

# %%
results[0].find('source')['srcset']
# Out:
# 'https://amc-theatres-res.cloudinary.com/image/upload/f_auto,fl_lossy,h_600,q_auto,w_400/v1553695740/amc-cdn/production/2/movies/45800/45840/PosterDynamic/75045.jpg'
